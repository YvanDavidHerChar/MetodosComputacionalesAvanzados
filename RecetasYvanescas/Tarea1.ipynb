# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-1,2, 100) # generamos un rango de valores en x

distro = np.ones(len(x)) # construimos la distribucion 
distro[x<=0] = 0
distro[x>1] = 0

plt.plot(x, distro) # y la graficamos
plt.ylim(0,1.1)
# Out:
# (0, 1.1)

# %%
l = np.random.uniform(size=100000) # generamos 100 mil elementos
_ = plt.hist(l, bins=100, density=True) # el histograma tiene 100 intervalos

# %%
l = np.random.uniform(size=100000)
_ = plt.hist(l, bins=100, density=True)

x = np.linspace(l.min(),l.max(), 100)
distro = np.ones(len(x))
plt.plot(x, distro)

# %%
l = np.random.normal(size=100000) # generamos puntos
_ = plt.hist(l, bins=100, density=True) #hacemos su histograma

x = np.linspace(l.min(),l.max(), 100) 
sigma = 1.0
distro = (1.0/np.sqrt(2.0*np.pi*sigma**2)) * np.exp(-(x**2)/(2.0*sigma**2))
plt.plot(x, distro) # comparamos la funcion de distribucion por comparacion

# %%
l = np.random.exponential(size=100000)
_ = plt.hist(l, bins=100, density=True)

x = np.linspace(l.min(),l.max(), 100)
distro = np.exp(-x)
plt.plot(x, distro)

# %% [raw]
# Genere un arreglo de 100000 puntos con valores entre 0 y 1 que al hacer su histograma siga la distribucion de probabilidad descrita por la siguiente figura.

# %%
x = np.linspace(0,1, 100) # generamos un rango de valores en x
linea = x*2
puntos = np.random.triangular(100000) # construimos el array con valores entre 0 y 1 
ii = puntos # lo encuadramos en los valores necesarios
_ = plt.hist(puntos, bins=100, density=True)
#distri = puntos
plt.plot(x,linea)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-c25a018df493> in <module>()
#       1 x = np.linspace(0,1, 100) # generamos un rango de valores en x
#       2 linea = x*2
# ----> 3 puntos = np.random.triangular(100000) # construimos el array con valores entre 0 y 1
#       4 ii = puntos # lo encuadramos en los valores necesarios
#       5 _ = plt.hist(puntos, bins=100, density=True)
#
# mtrand.pyx in mtrand.RandomState.triangular()
#
# TypeError: triangular() takes at least 3 positional arguments (1 given)
