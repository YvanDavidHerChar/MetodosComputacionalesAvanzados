# %%
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
data = pd.read_csv('USArrests.csv')
data = data.dropna()
Nombres = np.array(data[["Unnamed: 0"]])
data = data.drop("Unnamed: 0",axis=1)
X = np.array(data[["Murder","Assault","UrbanPop","Rape"]])
np.shape(Nombres)
# Out:
# (50, 1)

# %%
datosEscalados = StandardScaler().fit(X).transform(X)
pca = PCA(n_components=2)
losDats = pca.fit(datosEscalados)
losexises = pca.transform(datosEscalados)
componentes = pca.components_.T

print(componentes[2])
# Out:
# [ 0.27819087 -0.87280619]

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(losexises[:,0],losexises[:,1], c='w')
ax.set_xlabel('First Principal Component')
ax.set_ylabel('Second Principal Component')
for a , b , c in zip(Nombres[:,0],-losexises[:,0],losexises[:,1]):
    ax.annotate(a , (b,c))
ax.arrow(0,0,2*componentes[0,0],2*componentes[0,1], head_width=0.05, head_length=0.05,ec='orange',length_includes_head = True)
ax.arrow(0,0,2*componentes[1,0],2*componentes[1,1], head_width=0.05, head_length=0.05,ec='orange',length_includes_head = True)
ax.arrow(0,0,2*componentes[2,0],2*componentes[2,1], head_width=0.05, head_length=0.05,ec='orange',length_includes_head = True)
ax.arrow(0,0,2*componentes[3,0],2*componentes[3,1], head_width=0.05, head_length=0.05,ec='orange',length_includes_head = True)

# %%
pca = PCA(n_components=4)
losDats = pca.fit(datosEscalados)
variance = pca.explained_variance_ratio_
varianciaACU = np.cumsum(variance)
print(np.shape(variance))
fig , (la1, la2) = plt.subplots(ncols=2,figsize=(11,5))
la1.plot(variance)
la2.plot(varianciaACU)
# Out:
# (4,)

# %%
datos = pd.read_csv('Cars93.csv', usecols=[8,11,12,13,14,15,17,19,20,21,22,23,24,25])
datos = data.dropna()

# %%
varianza = []
x = np.linspace(1,4,4)
for i in range(len(x)):
    datosEscalados = StandardScaler().fit(datos).transform(datos)
    pca= PCA(n_components=i)
    fitteo = pca.fit(datosEscalados)
    losexs = pca.transform(datosEscalados)
    varianza.append(sum(pca.explained_variance_ratio_))
plt.plot(x,varianza)
# Out:
# /srv/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /srv/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
# /srv/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /srv/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
# ...
